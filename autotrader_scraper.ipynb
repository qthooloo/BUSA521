# %% [markdown]
# Scrape autotrader for listings

# %%
import requests
from bs4 import BeautifulSoup
import re
import datetime
import time
import json_fix

listings = []

class listing:
    def __init__(self, url):
        self.url = url
        self.id = self.parse_listingid(url)

    def parse_listingid(self, listing_url): 
        pattern = r'(?<=listingId=)\d{9}'
        match = re.search(pattern, listing_url)
        if match:
            return match.group()

    def parse_content(self):
        try:
            time.sleep(2.5) # to reduce timeout errors when running more than one instance
            print("Trying " + self.url)
            print("Loading page content..")
            self.response = requests.get(self.url)
            print("Parsing HTML...")
            self.content = BeautifulSoup(self.response.content, 'html.parser')
            #store page temporarily
            #self.content = content

            print("Parsing content...")
            #define regex to get the element that has all the data in it
            self.pattern = re.compile('.*vin.*', re.IGNORECASE)
            #load the element
            self.matches = self.content.find_all(text=self.pattern)

            #use string manipulation to pull data from the element
            
            #get price
            try:
                self.price = repr(self.matches[0]).split('"price":')[1].split(',')[0].replace('"','')
            except:
                self.price = "Missing"

            #get vin
            try:
                self.vin = repr(self.matches[0]).split('"vin":')[1].split(',')[0].replace('"','')
            except:
                self.vin = "Missing"
            
            #get odometer
            try:
                self.odometer = repr(self.matches[0]).split('"odometer":')[1].split('"')[1].replace('"','').replace(" mi","").replace(",","")
            except:
                self.odometer = "Missing"
            
            #get trim
            try:
                self.trim = repr(self.matches[0]).split('"trim":')[1].split('"')[1].replace('"','')
            except:
                self.trim = "Missing"

            #get year
            try:
                self.year = repr(self.matches[0]).split('"car_year":')[1].split(',')[0]
            except:
                self.year = "Missing"
            
            #calculate age
            try:
                self.age = int((datetime.datetime.now()).year) - int(self.year)
            except:
                self.age = None

            #get make
            try:
                self.make = repr(self.matches[0]).split('"makeName":')[1].split('"')[1].replace('"','').replace('[','')
            except:
                self.make = "Missing"
            
            #get model
            try:
                self.model = repr(self.matches[0]).split('"modelName":')[1].split('"')[1].replace('"','').replace('[','')
            except:
                self.model = "Missing"
            
            #get sale type
            try: 
                self.saletype = repr(self.matches[0]).split('"Car_Type":')[1].split('"')[1].replace('"','')
            except:
                self.saletype = "Missing"
            
            #get mpg
            try:
                self.mpg = repr(self.matches[0]).split('"fuelEconomy":[')[1].split(']')[0].replace('"','')
            except:
                self.mpg = "Missing"
            
            #get vehicle features
            self.features = []
            try:
                features = repr(self.matches[0]).split('"vehicleFeatures":[')[1].split(']')[0].replace('"','').split(",")
                for feature in features:
                    self.features.append(feature)
            except:
                self.features = None
        except ConnectionError:
            return "Lost Connection, skipping.."

def get_page_listings(pageurl):
    # Send a GET request to the URL
    response = requests.get(pageurl)

    # Check the status code of the response to make sure it was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using Beautiful Soup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the elements on the page that you want to scrape
        # For example, to get the text of all the links on the page:
        links = soup.find_all('a')
        for link in links:
            if link.has_attr('href') and 'vehicledetails' in link.get('href'):
                fullurl = originurl + link.get('href')
                new_listing = listing(fullurl)
                if 'clickType=spotlight' not in new_listing.url:
                    listing_ids = [listing.id for listing in listings]
                    if new_listing.id not in listing_ids:
                        listings.append(new_listing)
    else:
        print('Error: Failed to retrieve content')


originurl = 'http://www.autotrader.com/'
#baseurl = 'http://www.autotrader.com/cars-for-sale/all-cars/ford/f150/dallas-tx-75201?searchRadius=50&isNewSearch=false&marketExtension=include&showAccelerateBanner=false&sortBy=relevance&numRecords=100'
#baseurl = 'http://www.autotrader.com/cars-for-sale/toyota/camry/dallas-tx-75201?requestId=3P_CERT&listingTypes=CERTIFIED%2CUSED%2C3P_CERT&searchRadius=50&marketExtension=include&isNewSearch=true&showAccelerateBanner=false&sortBy=relevance&numRecords=100'
#baseurl = 'http://www.autotrader.com/cars-for-sale/nissan/altima/dallas-tx-75201?listingTypes=CERTIFIED%2CUSED&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100'
baseurl = 'http://www.autotrader.com/cars-for-sale/honda/accord/dallas-tx-75201?searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100'
pages = 6

# %%
#get links from each page of results
#1000 seems to be the limit
for i in range(pages + 1):
    if i == 0:
        get_page_listings(baseurl)
    if i >= 0:
        n = str(i*100)
        newurl = baseurl + "&firstRecord=" + n
        get_page_listings(newurl)
    i = i+1

#for l in listings:
    #print('URL:', l.url)
    #print('ID:', l.id)

# %%
import json
filename = "output.json"
listObj = []

# define a custom encoder function to handle the features list
def encode_features(obj):
    if isinstance(obj, list):
        return [str(item) for item in obj]
    else:
        return obj

def write_to_file(listing_dict):
    with open(filename, 'a') as f:
        json.dump(listing_dict, f, default=encode_features)
        f.write("\n")


for listing in listings:
    try:
        try:
            print(listing.vin + " already parsed")
            continue
        except AttributeError:
            try:
                listing.parse_content()
            except:
                print("Connection Rejected, Skipping")
                continue

        if listing.vin:
            # Create object that json serializer can comprehend
            listing_dict = {
                "url": listing.url,
                "id": listing.id,
                "price": listing.price,
                "vin": listing.vin,
                "odometer": listing.odometer,
                "trim": listing.trim,
                "year": listing.year,
                "age": listing.age,
                "make": listing.make,
                "model": listing.model,
                "saletype": listing.saletype,
                "mpg": listing.mpg,
                "features": listing.features
            }
            print("Writing listing for " + listing.vin + " to file.")
            write_to_file(listing_dict)    
    except ConnectionError:
        print("Connection Rejected, Waiting to retry..")
        time.sleep(240)
        continue
# Out:
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=667544495&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# C:\Users\Qthooloo\AppData\Local\Temp\ipykernel_8860\2382654883.py:36: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   self.matches = self.content.find_all(text=self.pattern)
# Writing listing for 1HGCV3F91LA015984 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673767724&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F36JA039324 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672968554&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F38KA100917 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672335349&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F32LA060903 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671578140&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F5XMA079539 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=669075133&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F30MA000559 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671486638&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F38KA021298 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=668587861&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F31MA102561 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673319404&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F54LA034935 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671455352&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F18JA175078 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673869923&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F52LA004810 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673849202&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F35DA245331 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673856772&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F38KA019017 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672613125&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F57JA142656 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671091612&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F43LA037901 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673597203&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F37NA068868 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673720828&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F33NA059195 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673607906&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F30NA060451 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673418693&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV3F28NA033632 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674016221&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F59MA101322 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672149456&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F16LA126688 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672928254&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F77FA141235 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671535719&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV3F98MA018947 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=666647929&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671864157&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F37FA093359 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673287694&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F85EA264006 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672869741&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673391137&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673693841&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F98JA063547 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671607642&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F38JA097905 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673566044&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F98JA219750 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673088636&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F50FA224231 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=668779251&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F34KA107055 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=658570012&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F32LA134174 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672395467&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV3F23NA025793 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=668560998&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F36EA198781 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=669545737&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F15KA094623 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=644793934&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F34MA059950 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=644770327&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F47MA000254 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=648967793&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F36NA021282 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=649133883&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F38NA037029 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=648967803&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F34NA049498 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671290423&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F96LA022732 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=651736303&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV3F20NA021569 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673670345&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR3F92EA019971 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671493322&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F82DA008629 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673607284&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F35LA001733 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673588797&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F36LA101422 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674016219&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F40LA142931 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672493540&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F97JA013206 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672863970&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F96MA023851 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672052233&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F37KA027979 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=670965184&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F39FA038279 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672853814&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F46LA076952 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=666631714&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671406264&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=670233634&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672082293&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F95JA011430 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=670805196&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672774041&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674016220&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F56KA041447 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674016183&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F38LA033883 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=668992687&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F83EA190567 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673806403&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673693839&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F48LA085619 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=660598850&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F36LA149731 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=664857148&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F32NA057695 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=659880586&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F35NA064706 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=660408059&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F48NA029201 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=671247701&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR3F89FA012928 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672368147&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for JHMCR6F32HC016121 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673391749&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F39LA086382 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673103422&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F42NA003919 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673748240&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCT1B87DA010801 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672514457&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR3F93HA031485 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=669129896&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F59HA245193 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673066394&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F36HA281891 to file.
# ...
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F34MA064016 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672211290&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for JHMCM564X4C015567 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673475485&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCM66526A036803 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673884710&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F97KA034578 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672344621&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674063891&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV2F35MA033914 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674010844&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F31KA027924 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674071200&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673108473&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F74FA114235 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674005792&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F34MA017200 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674064188&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for Missing to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674021728&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F19LA078989 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673647791&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F31MA046959 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674067595&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F36MA109294 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673800170&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR2F81FA180881 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674065169&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCG56471A119418 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=665205270&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F13KA071972 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674075329&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCM66827A039955 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673695246&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV3F17JA002311 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673757670&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCP3F81AA018303 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=664657442&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCV1F35MA101008 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=674070918&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR3F88DA043715 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673897813&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCP2F48CA218542 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=673917087&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCS2B86BA008639 to file.
# Trying http://www.autotrader.com//cars-for-sale/vehicledetails.xhtml?listingId=672686018&makeCodeList=HONDA&modelCodeList=ACCORD&city=Dallas&state=TX&zip=75201&searchRadius=50&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=500&listingTypes=USED&referrer=%2Fcars-for-sale%2Fhonda%2Faccord%2Fdallas-tx-75201%3FsearchRadius%3D50%26marketExtension%3Dinclude%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D100%26firstRecord%3D500&clickType=listing
# Loading page content..
# Parsing HTML...
# Parsing content...
# Writing listing for 1HGCR3F98HA027920 to file.
